# %% [markdown]
# ## **Data Cleaning**

# %%
import pandas as pd

# %%
df=pd.read_csv('unclean_smartwatch_health_data.csv')

# %% [markdown]
# ## **Data Assesment**

# %%
df.head()
# Out:
#    User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0   4174.0         58.939776               98.809650   5450.390578
# 1      NaN               NaN               98.532195    727.601610
# 2   1860.0        247.803052               97.052954   2826.521994
# 3   2294.0         40.000000               96.894213  13797.338044
# 4   2130.0         61.950165               98.583797  15679.067648
#
#   Sleep Duration (hours) Activity Level Stress Level
# 0      7.167235622316564  Highly Active            1
# 1      6.538239375570314  Highly_Active            5
# 2                  ERROR  Highly Active            5
# 3      7.367789630207228          Actve            3
# 4                    NaN  Highly_Active            6

# %%
df.tail()
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)   Step Count  \
# 9995   1524.0         78.819386               98.931927  2948.491953
# 9996   4879.0         48.632659               95.773035  4725.623070
# 9997   2624.0         73.834442               97.945874  2571.492060
# 9998   4907.0               NaN               98.401058  3364.788855
# 9999   4113.0         70.063864               98.475606   544.696104
#
#      Sleep Duration (hours) Activity Level Stress Level
# 9995      7.402748595032027         Active            7
# 9996     6.3821659358529015      Sedentary            2
# 9997       6.91654920303435      Sedentary            4
# 9998      5.691233932149209         Active            8
# 9999      5.691001039740254          Actve            5

# %%
df.sample(5)
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)   Step Count  \
# 8660   2137.0         81.447972               97.695447  4158.686958
# 6932   4713.0         46.134661               99.815113  1301.025073
# 1938   1101.0         96.605339               97.594000  1301.157054
# 8739   4946.0         77.241538               98.377888  7307.604198
# 9662   4956.0         76.556313               97.638525  2844.189496
#
#      Sleep Duration (hours) Activity Level Stress Level
# 8660      4.520597119137852         Active            2
# 6932      6.870182589175571  Highly Active            6
# 1938      3.497280946802083      Sedentary            2
# 8739      4.839081879208614          Actve            5
# 9662       5.52959455610948          Actve            1

# %%
df.describe()
# Out:
#            User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count
# count  9799.000000       9600.000000             9700.000000   9900.000000
# mean   3007.480253         76.035462               97.841581   6985.685885
# std    1150.581542         19.412483                1.732863   6885.809680
# min    1001.000000         40.000000               90.791208      0.910138
# 25%    1997.500000         64.890152               96.662683   2021.039657
# 50%    2998.000000         75.220601               98.010642   4962.534599
# 75%    4004.000000         85.198249               99.376179   9724.902880
# max    4999.000000        296.593970              100.000000  62486.690753

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   User ID                 9799 non-null   float64
#  1   Heart Rate (BPM)        9600 non-null   float64
#  2   Blood Oxygen Level (%)  9700 non-null   float64
#  3   Step Count              9900 non-null   float64
#  4   Sleep Duration (hours)  9850 non-null   str
#  5   Activity Level          9800 non-null   str
#  6   Stress Level            9800 non-null   str
# dtypes: float64(4), str(3)
# memory usage: 547.0 KB

# %%
df.shape
# Out:
# (10000, 7)

# %%
## Total Number of Missing Values inside my Dataset in each and every single column

## isnull()---> True

# %%
df.isnull().sum()
# Out:
# User ID                   201
# Heart Rate (BPM)          400
# Blood Oxygen Level (%)    300
# Step Count                100
# Sleep Duration (hours)    150
# Activity Level            200
# Stress Level              200
# dtype: int64

# %%
### Duplicate values --->

#### duplicated().sum()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
### drop_duplicates() ---> removing all of the duplicate values

# %%
df.head()
# Out:
#    User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0   4174.0         58.939776               98.809650   5450.390578
# 1      NaN               NaN               98.532195    727.601610
# 2   1860.0        247.803052               97.052954   2826.521994
# 3   2294.0         40.000000               96.894213  13797.338044
# 4   2130.0         61.950165               98.583797  15679.067648
#
#   Sleep Duration (hours) Activity Level Stress Level
# 0      7.167235622316564  Highly Active            1
# 1      6.538239375570314  Highly_Active            5
# 2                  ERROR  Highly Active            5
# 3      7.367789630207228          Actve            3
# 4                    NaN  Highly_Active            6

# %% [markdown]
# ### Data Assessment
#
# #### What all different results you came up with for your data
#
# #### Remove User ID Column

# %%
df['Heart Rate (BPM)'].isnull().sum()
# Out:
# np.int64(400)

# %%
df['Heart Rate (BPM)'].value_counts()
# Out:
# Heart Rate (BPM)
# 40.000000     84
# 58.939776      1
# 247.803052     1
# 61.950165      1
# 96.285938      1
#               ..
# 77.912299      1
# 78.819386      1
# 48.632659      1
# 73.834442      1
# 70.063864      1
# Name: count, Length: 9517, dtype: int64

# %%
df[df['Heart Rate (BPM)']==296.5939695131042]
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 4185   4643.0         296.59397               95.415588  54698.646371
#
#      Sleep Duration (hours) Activity Level Stress Level
# 4185        8.4611474189254            NaN           10

# %%
df['Heart Rate (BPM)'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.dropna(subset=['Heart Rate (BPM)'],inplace=True)

# %%
df['Heart Rate (BPM)'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['User ID', 'Heart Rate (BPM)', 'Blood Oxygen Level (%)', 'Step Count',
#        'Sleep Duration (hours)', 'Activity Level', 'Stress Level'],
#       dtype='str')

# %%
df=df[['Heart Rate (BPM)', 'Blood Oxygen Level (%)', 'Step Count',
       'Sleep Duration (hours)', 'Activity Level', 'Stress Level']]

# %%
df['Heart Rate (BPM)'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Heart Rate (BPM)']=df['Heart Rate (BPM)'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9600 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        9600 non-null   float32
#  1   Blood Oxygen Level (%)  9311 non-null   float64
#  2   Step Count              9506 non-null   float64
#  3   Sleep Duration (hours)  9455 non-null   str
#  4   Activity Level          9409 non-null   str
#  5   Stress Level            9407 non-null   str
# dtypes: float32(1), float64(2), str(3)
# memory usage: 487.5 KB

# %%
df['Blood Oxygen Level (%)']=df['Blood Oxygen Level (%)'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9600 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        9600 non-null   float32
#  1   Blood Oxygen Level (%)  9311 non-null   float32
#  2   Step Count              9506 non-null   float64
#  3   Sleep Duration (hours)  9455 non-null   str
#  4   Activity Level          9409 non-null   str
#  5   Stress Level            9407 non-null   str
# dtypes: float32(2), float64(1), str(3)
# memory usage: 450.0 KB

# %%
df['Step Count']=df['Step Count'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9600 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        9600 non-null   float32
#  1   Blood Oxygen Level (%)  9311 non-null   float32
#  2   Step Count              9506 non-null   float32
#  3   Sleep Duration (hours)  9455 non-null   str
#  4   Activity Level          9409 non-null   str
#  5   Stress Level            9407 non-null   str
# dtypes: float32(3), str(3)
# memory usage: 412.5 KB

# %%
df['Blood Oxygen Level (%)'].isnull().sum()
# Out:
# np.int64(289)

# %%
df['Blood Oxygen Level (%)'].mean()
# Out:
# np.float32(97.8443)

# %%
df['Blood Oxygen Level (%)'].fillna(97.8443,inplace=True)
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_6024\3685568387.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Blood Oxygen Level (%)'].fillna(97.8443,inplace=True)
# 0       98.809647
# 2       97.052956
# 3       96.894211
# 4       98.583794
# 5       94.202911
#           ...
# 9994    98.640579
# 9995    98.931931
# 9996    95.773033
# 9997    97.945877
# 9999    98.475609
# Name: Blood Oxygen Level (%), Length: 9600, dtype: float32

# %%
df['Blood Oxygen Level (%)'].isnull().sum()
# Out:
# np.int64(289)

# %%
df.head()
# Out:
#    Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0         58.939777               98.809647   5450.390625
# 2        247.803055               97.052956   2826.521973
# 3         40.000000               96.894211  13797.337891
# 4         61.950165               98.583794  15679.067383
# 5         96.285934               94.202911  10205.992188
#
#   Sleep Duration (hours) Activity Level Stress Level
# 0      7.167235622316564  Highly Active            1
# 2                  ERROR  Highly Active            5
# 3      7.367789630207228          Actve            3
# 4                    NaN  Highly_Active            6
# 5      8.378342673824589  Highly_Active           10

# %%
df['Step Count'].isnull().sum()
# Out:
# np.int64(94)

# %%
df.dropna(subset='Step Count', inplace=True)

# %%
df['Step Count'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Activity Level'].value_counts()
# Out:
# Activity Level
# Seddentary       1594
# Sedentary        1583
# Highly Active    1568
# Actve            1554
# Active           1544
# Highly_Active    1473
# Name: count, dtype: int64

# %%
df['Activity Level'].isnull().sum()
# Out:
# np.int64(190)

# %%
df=df[df['Sleep Duration (hours)']!='ERROR']

# %%
df['Sleep Duration (hours)'].value_counts()
# Out:
# Sleep Duration (hours)
# 7.167235622316564     1
# 7.367789630207228     1
# 8.378342673824589     1
# 7.871146008904113     1
# 5.224139066195455     1
#                      ..
# 5.428634630125767     1
# 7.402748595032027     1
# 6.3821659358529015    1
# 6.91654920303435      1
# 5.691001039740254     1
# Name: count, Length: 9128, dtype: int64

# %%
df['Sleep Duration (hours)']=df['Sleep Duration (hours)'].astype('float32')

# %%
df['Sleep Duration (hours)'].max()
# Out:
# np.float32(12.140233)

# %%
### Removing Outliers

# %%
df=df[df['Sleep Duration (hours)']<12.0]

# %%
df['Sleep Duration (hours)'].max()
# Out:
# np.float32(11.908386)

# %%
df.head()
# Out:
#    Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0         58.939777               98.809647   5450.390625
# 3         40.000000               96.894211  13797.337891
# 5         96.285934               94.202911  10205.992188
# 6         47.272255               95.389763   3208.781250
# 7         81.733498               95.981346   6051.250000
#
#    Sleep Duration (hours) Activity Level Stress Level
# 0                7.167236  Highly Active            1
# 3                7.367790          Actve            3
# 5                8.378343  Highly_Active           10
# 6                7.871146     Seddentary            2
# 7                5.224139      Sedentary            1

# %%
df['Activity Level'].isnull().sum()
# Out:
# np.int64(187)

# %%
df.dropna(subset='Activity Level', inplace=True)

# %%
df['Activity Level'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Stress Level'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['Stress Level'].value_counts()
# Out:
# Stress Level
# 2            908
# 6            896
# 1            893
# 7            892
# 3            889
# 4            868
# 9            865
# 5            848
# 10           839
# 8            817
# Very High     42
# Name: count, dtype: int64

# %%
df['Stress Level'].isnull().sum()
# Out:
# np.int64(183)

# %%
df['Stress Level'].fillna(5,inplace=True)
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_6024\1190028874.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Stress Level'].fillna(5,inplace=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[275], line 1
# ----> 1 df['Stress Level'].fillna(5,inplace=True)
#
# File c:\Users\abhis\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:7086, in NDFrame.fillna(self, value, axis, inplace, limit)
#    7082                     "or Series, but you passed a "
#    7083                     f'"{type(value).__name__}"'
#    7084                 )
#    7085
# -> 7086             new_data = self._mgr.fillna(value=value, limit=limit, inplace=inplace)
#    7087
#    7088         elif isinstance(value, (dict, ABCSeries)):
#    7089             result = self if inplace else self.copy(deep=False)
#
# File c:\Users\abhis\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:461, in BaseBlockManager.fillna(self, value, limit, inplace)
#     457 if limit is not None:
#     458     # Do this validation even if we go through one of the no-op paths
#     459     limit = libalgos.validate_limit(None, limit=limit)
# --> 461 return self.apply(
#     462     "fillna",
#     463     value=value,
#     464     limit=limit,
#     465     inplace=inplace,
#     466 )
#
# File c:\Users\abhis\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:445, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     443         applied = b.apply(f, **kwargs)
#     444     else:
# --> 445         applied = getattr(b, f)(**kwargs)
#     446     result_blocks = extend_blocks(applied, result_blocks)
#     448 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File c:\Users\abhis\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\blocks.py:1893, in ExtensionBlock.fillna(self, value, limit, inplace)
#    1891     if isinstance(self.dtype, IntervalDtype) and limit is not None:
#    1892         raise ValueError("limit must be None")
# -> 1893     return super().fillna(
#    1894         value=value,
#    1895         limit=limit,
#    1896         inplace=inplace,
#    1897     )
#    1898 if self._can_hold_na and not self.values._hasna:
#    1899     refs = self.refs
#
# File c:\Users\abhis\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\blocks.py:1342, in Block.fillna(self, value, limit, inplace)
#    1339     mask[mask.cumsum(self.values.ndim - 1) > limit] = False
#    1341 if inplace:
# -> 1342     nbs = self.putmask(mask.T, value)
#    1343 else:
#    1344     nbs = self.where(value, ~mask.T)
#
# File c:\Users\abhis\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\blocks.py:1774, in EABackedBlock.putmask(self, mask, new)
#    1770     values = values.T
#    1772 try:
#    1773     # Caller is responsible for ensuring matching lengths
# -> 1774     values._putmask(mask, new)
#    1775 except OutOfBoundsDatetime:
#    1776     raise
#
# File c:\Users\abhis\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arrays\string_.py:889, in StringArray._putmask(self, mask, value)
#     885 def _putmask(self, mask: npt.NDArray[np.bool_], value) -> None:
#     886     # the super() method NDArrayBackedExtensionArray._putmask uses
#     887     # np.putmask which doesn't properly handle None/pd.NA, so using the
#     888     # base class implementation that uses __setitem__
# --> 889     ExtensionArray._putmask(self, mask, value)
#
# File c:\Users\abhis\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arrays\base.py:2585, in ExtensionArray._putmask(self, mask, value)
#    2582 else:
#    2583     val = value
# -> 2585 self[mask] = val
#
# File c:\Users\abhis\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arrays\string_.py:865, in StringArray.__setitem__(self, key, value)
#     862 if self._readonly:
#     863     raise ValueError("Cannot modify read-only array")
# --> 865 value = self._maybe_convert_setitem_value(value)
#     867 key = check_array_indexer(self, key)
#     868 scalar_key = lib.is_scalar(key)
#
# File c:\Users\abhis\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arrays\string_.py:839, in StringArray._maybe_convert_setitem_value(self, value)
#     837         value = self.dtype.na_value
#     838     elif not isinstance(value, str):
# --> 839         raise TypeError(
#     840             f"Invalid value '{value}' for dtype '{self.dtype}'. Value should "
#     841             f"be a string or missing value, got '{type(value).__name__}' "
#     842             "instead."
#     843         )
#     844 else:
#     845     value = extract_array(value, extract_numpy=True)
#
# TypeError: Invalid value '5' for dtype 'str'. Value should be a string or missing value, got 'int' instead.

# %%
df['Stress Level'].isnull().sum()
# Out:
# np.int64(183)

# %%
df.dropna(subset='Stress Level', inplace=True)

# %%
df['Stress Level'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0         58.939777               98.809647   5450.390625
# 3         40.000000               96.894211  13797.337891
# 5         96.285934               94.202911  10205.992188
# 6         47.272255               95.389763   3208.781250
# 7         81.733498               95.981346   6051.250000
#
#    Sleep Duration (hours) Activity Level Stress Level
# 0                7.167236  Highly Active            1
# 3                7.367790          Actve            3
# 5                8.378343  Highly_Active           10
# 6                7.871146     Seddentary            2
# 7                5.224139      Sedentary            1
